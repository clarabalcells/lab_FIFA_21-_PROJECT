# %%
#During this afternoon session, each member of the group must write a function which:

#takes a dataframe as input
#perform the data cleaning operations on the assigned columns
#return a new cleaned dataframe.
#Then put all you group member functions into the group jupyter notebook.

#BONUS
#Try to create a new function called preprocess which"

#takes a dataframe as input
#call all the other group member functions and apply them to the starting dataframe
#return a clean dataframe.

# %%
import pandas as pd
import numpy as np
import glob

# %%
fifa = pd.read_csv('fifa21_train.csv')
fifa
# Out:
#            ID            Name  Age  Nationality                        Club  \
# 0      184383       A. Pasche   26  Switzerland           FC Lausanne-Sport
# 1      188044   Alan Carvalho   30     China PR     Beijing Sinobo Guoan FC
# 2      184431     S. Giovinco   33        Italy                    Al Hilal
# 3      233796        J. Evans   22        Wales                Swansea City
# 4      234799      Y. Demoncy   23       France  US Orléans Loiret Football
# ...       ...             ...  ...          ...                         ...
# 11696  232504   B. Böðvarsson   25      Iceland       Jagiellonia Białystok
# 11697  214680       G. Gallon   27       France                ESTAC Troyes
# 11698  221489       J. Flores   22        Chile              CD Antofagasta
# 11699  146717  Anderson Silva   26       Brazil                    Barnsley
# 11700  236507     T. Conechny   22    Argentina            Portland Timbers
#
# ...

# %%
column_names = fifa.columns
column_names
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Club', 'BP', 'Position',
#        'Team & Contract', 'Height', 'Weight',
#        ...
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'GK', 'OVA'],
#       dtype='object', length=101)

# %%
fifa.shape
# Out:
# (11701, 101)

# %%
fifa.describe()
# Out:
#                   ID          Age        Growth     Attacking      Crossing  \
# count   11701.000000  11701.00000  11701.000000  11701.000000  11701.000000
# mean   219436.649004     25.27049      5.534655    258.482181     51.593795
# std     37480.006004      4.95764      5.810903     72.267012     17.872747
# min        27.000000     16.00000     -1.000000     33.000000      6.000000
# 25%    204060.000000     21.00000      0.000000    232.000000     41.000000
# 50%    229040.000000     25.00000      4.000000    271.000000     56.000000
# 75%    244176.000000     29.00000     10.000000    306.000000     65.000000
# max    259090.000000     43.00000     26.000000    437.000000     94.000000
#
#           Finishing  Heading Accuracy  Short Passing       Volleys  \
# count  11701.000000      11701.000000   11701.000000  11660.000000
# mean      48.048116         53.494060      60.436800     45.067324
# std       19.399617         16.956195      13.971811     17.732902
# ...

# %%
best_teams = clubs.sort_values(by = 'Growth', ascending=False)

best_teams
# Out:
#                                  ID   Age  Growth  Attacking  Crossing  \
# Club
# SC Beira Mar               210032.0  17.0    19.0     264.00     58.00
# Halmstads BK               241415.0  18.0    19.0     213.00     26.00
# Cúcuta Deportivo           247314.0  18.0    17.0     214.00     40.00
# VfR Aalen                  240009.0  19.0    17.0     198.00     33.00
# Cesena                     242838.0  18.0    16.0     213.00     42.00
# ...                             ...   ...     ...        ...       ...
# Atlético Clube Goianiense  231277.0  22.0     0.0     281.75     62.25
# Al Qadisiyah               173703.0  29.0     0.0     272.00     60.00
# FC Orenburg                201259.0  28.0     0.0     340.00     66.00
# Albirex Niigata            203344.0  27.0     0.0     337.00     68.00
# US Créteil-Lusitanos       175953.5  27.5    -0.5     201.50     30.50
#
#                            Finishing  Heading Accuracy  Short Passing  \
# Club
# ...

# %%
type(fifa.iloc[0])
# Out:
# pandas.core.series.Series

# %%
best_attack = fifa.sort_values(by = 'Attacking', ascending=False)
best_attack
# Out:
#           ID               Name  Age Nationality               Club  BP  \
# 8048   20801  Cristiano Ronaldo   35    Portugal           Juventus  ST
# 5291  158023           L. Messi   33   Argentina       FC Barcelona  RW
# 9893  165153         K. Benzema   32      France        Real Madrid  CF
# 3856  194765       A. Griezmann   29      France       FC Barcelona  ST
# 2219  188545     R. Lewandowski   31      Poland  FC Bayern München  ST
# ...      ...                ...  ...         ...                ...  ..
# 5848  233977   Eduardo Fonseira   20      Brazil           Botafogo  GK
# 1530  245306          L. Sáreda   28     Uruguay            Uruguay  GK
# 3268  230312      Gabri Prestão   28      Brazil      Internacional  GK
# 4326  242879     M. Vandevoordt   18     Belgium           KRC Genk  GK
# 1778  168566        L. Martínez   27    Colombia        Sakaryaspor  GK
#
#       Position                Team & Contract Height  Weight  ...   CDM   RDM  \
# ...

# %%
best_skill = fifa.sort_values(by = 'Skill', ascending=False)
best_skill
# Out:
#            ID              Name  Age     Nationality                 Club  \
# 5291   158023          L. Messi   33       Argentina         FC Barcelona
# 4782   190871         Neymar Jr   28          Brazil  Paris Saint-Germain
# 9219   192985      K. De Bruyne   29         Belgium      Manchester City
# 5811   189513            Parejo   31           Spain        Villarreal CF
# 4180    10535              Xavi   34           Spain         FC Barcelona
# ...       ...               ...  ...             ...                  ...
# 4809   251995    João Gonçalves   19        Portugal          Boavista FC
# 8661   245090     L. Beckemeyer   20         Germany        VfL Osnabrück
# 10247  251164           K. Harr   20  Korea Republic    FC Erzgebirge Aue
# 2601   233999     Jairo Farnias   20          Brazil        Internacional
# 5848   233977  Eduardo Fonseira   20          Brazil             Botafogo
#
#         BP  Position                  Team & Contract Height  Weight  ...  \
# ...

# %%
best_heading_accuracy = fifa.sort_values(by = 'Heading Accuracy', ascending=False)
best_heading_accuracy
# Out:
#            ID            Name  Age  Nationality                        Club  \
# 5304   205850    L. Pavoletti   31        Italy                    Cagliari
# 6948   155862    Sergio Ramos   34        Spain                 Real Madrid
# 11354  189068         B. Dost   31  Netherlands         Eintracht Frankfurt
# 3779   176944     M. Fellaini   32      Belgium  Shandong Luneng TaiShan FC
# 5905   176957  Felipe Santana   29       Brazil             Kuban Krasnodar
# ...       ...             ...  ...          ...                         ...
# 1530   245306       L. Sáreda   28      Uruguay                     Uruguay
# 2601   233999   Jairo Farnias   20       Brazil               Internacional
# 10399  257405       D. Ndiaye   20      Senegal              Stade de Reims
# 4206   257287      J. Wehking   20      Germany             Fortuna Sittard
# 6656   241207    K. Yoshimaru   24        Japan                 Vissel Kobe
#
# ...

# %%
best_finishing = fifa.sort_values(by = 'Finishing', ascending=False)
best_finishing
# Out:
#            ID               Name  Age Nationality  \
# 8048    20801  Cristiano Ronaldo   35    Portugal
# 5291   158023           L. Messi   33   Argentina
# 7848   202126            H. Kane   26     England
# 2219   188545     R. Lewandowski   31      Poland
# 7410   153079          S. Agüero   32   Argentina
# ...       ...                ...  ...         ...
# 3124   257638         L. Philipp   19     Germany
# 4015   241206         D. Maekawa   25       Japan
# 4326   242879     M. Vandevoordt   18     Belgium
# 4110   247020         W. Bedfian   18      France
# 10399  257405          D. Ndiaye   20     Senegal
#
#                                 Club  BP  Position  \
# 8048                        Juventus  ST     ST LW
# 5291                    FC Barcelona  RW  RW ST CF
# 7848               Tottenham Hotspur  ST        ST
# 2219               FC Bayern München  ST        ST
# 7410                 Manchester City  ST        ST
# ...

# %%
#Possible irrelevant data

 #nationality, Height and Weight

# %%
best_gk = pd.DataFrame('BP', 'Skill')
best_gk
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [50], in <cell line: 1>()
# ----> 1 best_gk = pd.DataFrame('BP', 'Skill')
#       2 best_gk
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:756, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     753 # For data is scalar
#     754 else:
#     755     if index is None or columns is None:
# --> 756         raise ValueError("DataFrame constructor not properly called!")
#     758     # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#     759     # expected "Union[Union[Union[ExtensionArray, ndarray],
#     760     # Index, Series], Sequence[Any]]"
#     761     index = ensure_index(index)  # type: ignore[arg-type]
#
# ValueError: DataFrame constructor not properly called!

# %%
best_gk = fifa.sort_values(by = 'Skill', ascending=False); fifa.sort_values (by = 'BP',ascending=False)

best_gk
# Out:
#            ID              Name  Age     Nationality                 Club  \
# 5291   158023          L. Messi   33       Argentina         FC Barcelona
# 4782   190871         Neymar Jr   28          Brazil  Paris Saint-Germain
# 9219   192985      K. De Bruyne   29         Belgium      Manchester City
# 5811   189513            Parejo   31           Spain        Villarreal CF
# 4180    10535              Xavi   34           Spain         FC Barcelona
# ...       ...               ...  ...             ...                  ...
# 4809   251995    João Gonçalves   19        Portugal          Boavista FC
# 8661   245090     L. Beckemeyer   20         Germany        VfL Osnabrück
# 10247  251164           K. Harr   20  Korea Republic    FC Erzgebirge Aue
# 2601   233999     Jairo Farnias   20          Brazil        Internacional
# 5848   233977  Eduardo Fonseira   20          Brazil             Botafogo
#
#         BP  Position                  Team & Contract Height  Weight  ...  \
# ...
